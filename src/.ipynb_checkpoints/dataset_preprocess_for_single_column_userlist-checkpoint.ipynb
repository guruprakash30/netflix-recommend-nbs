# %%
import pandas as pd

# Step 2: Read the CSV file (replace 'ratings_small.csv' with your actual file path)
df = pd.read_csv('ratings_small.csv')

# Step 3: Select only the 'movieId' column
movie_ids = df[['userId']]

# Step 4: Write this column to a new CSV file
movie_ids.to_csv('user_ids_only.csv', index=False)

# Optional: display first few rows to verify
movie_ids.head()
